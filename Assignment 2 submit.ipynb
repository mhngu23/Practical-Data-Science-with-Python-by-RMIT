# %%
# Import pandas library
import pandas as pd
pd.set_option('display.max_columns',30)
pd.set_option('display.max_rows',600)
from pandas.plotting import scatter_matrix

# %%
# Import numpy library
import numpy as np

# %%
# Import MatplotLib
import matplotlib.pyplot as plt

# %%
# Import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.utils import shuffle
from sklearn.tree import DecisionTreeClassifier

# %%
# Import seaborn
import seaborn as sns

# %% [markdown]
#    # Task 1: Retrieving and Preparing the Data

# %% [markdown]
# ## 1.1 Data Retrieving

# %%
blood_transfusion_filename = 'transfusion.data'

# %%
blood_transfusion_data = pd.read_csv(blood_transfusion_filename,sep=',',decimal='.',header = 0)

# %%
blood_transfusion_data.shape
# Out:
# (748, 5)

# %%
blood_transfusion_data.head()
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# 0                 2                 50                  12500             98
# 1                 0                 13                   3250             28
# 2                 1                 16                   4000             35
# 3                 2                 20                   5000             45
# 4                 1                 24                   6000             77
#
#    whether he/she donated blood in March 2007
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           0

# %%
blood_transfusion_data.tail()
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 743                23                  2                    500
# 744                21                  2                    500
# 745                23                  3                    750
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 743             38                                           0
# 744             52                                           0
# 745             62                                           0
# 746             39                                           0
# 747             72                                           0

# %% [markdown]
# ## 1.2 Initial Data Inspection

# %%
blood_transfusion_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 748 entries, 0 to 747
# Data columns (total 5 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Recency (months)                            748 non-null    int64
#  1   Frequency (times)                           748 non-null    int64
#  2   Monetary (c.c. blood)                       748 non-null    int64
#  3   Time (months)                               748 non-null    int64
#  4   whether he/she donated blood in March 2007  748 non-null    int64
# dtypes: int64(5)
# memory usage: 29.3 KB

# %%
blood_transfusion_data.describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# count        748.000000         748.000000             748.000000
# mean           9.506684           5.514706            1378.676471
# std            8.095396           5.839307            1459.826781
# min            0.000000           1.000000             250.000000
# 25%            2.750000           2.000000             500.000000
# 50%            7.000000           4.000000            1000.000000
# 75%           14.000000           7.000000            1750.000000
# max           74.000000          50.000000           12500.000000
#
#        Time (months)  whether he/she donated blood in March 2007
# count     748.000000                                  748.000000
# mean       34.282086                                    0.237968
# std        24.376714                                    0.426124
# min         2.000000                                    0.000000
# 25%        16.000000                                    0.000000
# 50%        28.000000                                    0.000000
# 75%        50.000000                                    0.000000
# max        98.000000                                    1.000000

# %%
blood_transfusion_data.hist(bins=20,figsize=(20,15))
plt.show()

# %%
blood_transfusion_data['whether he/she donated blood in March 2007'].value_counts()
# Out:
# 0    570
# 1    178
# Name: whether he/she donated blood in March 2007, dtype: int64

# %%
blood_transfusion_data['whether he/she donated blood in March 2007'].value_counts()
# Out:
# 0    570
# 1    178
# Name: whether he/she donated blood in March 2007, dtype: int64

# %%
blood_transfusion_data['whether he/she donated blood in March 2007'].describe()
# Out:
# count    748.000000
# mean       0.237968
# std        0.426124
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: whether he/she donated blood in March 2007, dtype: float64

# %% [markdown]
# # Task 2: Data Exploration

# %%
corr_matrix = blood_transfusion_data.corr()

# %%
corr_matrix['Recency (months)'].sort_values(ascending = False)
# Out:
# Recency (months)                              1.000000
# Time (months)                                 0.160618
# Frequency (times)                            -0.182745
# Monetary (c.c. blood)                        -0.182745
# whether he/she donated blood in March 2007   -0.279869
# Name: Recency (months), dtype: float64

# %%
corr_matrix['Frequency (times)'].sort_values(ascending = False)
# Out:
# Frequency (times)                             1.000000
# Monetary (c.c. blood)                         1.000000
# Time (months)                                 0.634940
# whether he/she donated blood in March 2007    0.218633
# Recency (months)                             -0.182745
# Name: Frequency (times), dtype: float64

# %%
corr_matrix['Monetary (c.c. blood)'].sort_values(ascending = False)
# Out:
# Monetary (c.c. blood)                         1.000000
# Frequency (times)                             1.000000
# Time (months)                                 0.634940
# whether he/she donated blood in March 2007    0.218633
# Recency (months)                             -0.182745
# Name: Monetary (c.c. blood), dtype: float64

# %%
corr_matrix['Time (months)'].sort_values(ascending = False)
# Out:
# Time (months)                                 1.000000
# Monetary (c.c. blood)                         0.634940
# Frequency (times)                             0.634940
# Recency (months)                              0.160618
# whether he/she donated blood in March 2007   -0.035854
# Name: Time (months), dtype: float64

# %%
corr_matrix['whether he/she donated blood in March 2007'].sort_values(ascending = False)
# This means that there is some positive relationship between whether he/she donated blood in March 2007 with frequency and monetary
# Out:
# whether he/she donated blood in March 2007    1.000000
# Frequency (times)                             0.218633
# Monetary (c.c. blood)                         0.218633
# Time (months)                                -0.035854
# Recency (months)                             -0.279869
# Name: whether he/she donated blood in March 2007, dtype: float64

# %%
attributes = ["Recency (months)","Frequency (times)","Monetary (c.c. blood)","Time (months)","whether he/she donated blood in March 2007"]
scatter_matrix(blood_transfusion_data[attributes],figsize=(16,12))
plt.show()

# %% [markdown]
# ## Task 2.1 Column Investigation

# %%
blood_transfusion_data['Recency (months)'].describe()
# Out:
# count    748.000000
# mean       9.506684
# std        8.095396
# min        0.000000
# 25%        2.750000
# 50%        7.000000
# 75%       14.000000
# max       74.000000
# Name: Recency (months), dtype: float64

# %%
plt.hist(blood_transfusion_data['Recency (months)'],bins=10)
plt.xlabel('Recency (months)')
plt.ylabel('Count')
plt.title('Figure 1: Histogram Recency Distribution')
plt.show()

# %%
blood_transfusion_data.boxplot(column='Recency (months)',figsize = (5,5))
plt.title('Figure 2: Boxplot Recency Distribution')
plt.show()

# %%
blood_transfusion_data.loc[blood_transfusion_data['Recency (months)']>24,:]
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 475                26                  5                   1250
# 495                35                  3                    750
# 496                38                  1                    250
# 497                38                  1                    250
# 498                40                  1                    250
# 499                74                  1                    250
# 726                25                  6                   1500
# 746                39                  1                    250
# 747                72                  1                    250
#
#      Time (months)  whether he/she donated blood in March 2007
# 475             49                                           1
# 495             64                                           0
# 496             38                                           0
# 497             38                                           0
# 498             40                                           0
# 499             74                                           0
# 726             50                                           0
# 746             39                                           0
# 747             72                                           0

# %%
blood_transfusion_data['Frequency (times)'].describe()
# Out:
# count    748.000000
# mean       5.514706
# std        5.839307
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        7.000000
# max       50.000000
# Name: Frequency (times), dtype: float64

# %%
plt.hist(blood_transfusion_data['Frequency (times)'],bins=10)
plt.xlabel('Frequency (times)')
plt.ylabel('Count')
plt.title('Figure 3: Histogram Frequency Distribution')
plt.show()

# %%
blood_transfusion_data.boxplot(column='Frequency (times)',figsize = (5,5))
plt.title('Figure 4: Boxplot Frequency Distribution')
plt.show()

# %%
blood_transfusion_data.loc[blood_transfusion_data['Frequency (times)']<5.5,:].count()
# Out:
# Recency (months)                              481
# Frequency (times)                             481
# Monetary (c.c. blood)                         481
# Time (months)                                 481
# whether he/she donated blood in March 2007    481
# dtype: int64

# %%
blood_transfusion_data['Monetary (c.c. blood)'].describe()
# Out:
# count      748.000000
# mean      1378.676471
# std       1459.826781
# min        250.000000
# 25%        500.000000
# 50%       1000.000000
# 75%       1750.000000
# max      12500.000000
# Name: Monetary (c.c. blood), dtype: float64

# %%
plt.hist(blood_transfusion_data['Monetary (c.c. blood)'],bins=10)
plt.xlabel('Monetary (c.c. blood)')
plt.ylabel('Count')
plt.title('Figure 5: Histogram Monetary Distribution')
plt.show()

# %%
blood_transfusion_data.boxplot(column='Monetary (c.c. blood)',figsize = (5,5))
plt.title('Figure 6: Boxplot Monetary Distribution')
plt.show()

# %%
blood_transfusion_data.loc[blood_transfusion_data['Monetary (c.c. blood)']<1378.6,:].count()
# Out:
# Recency (months)                              481
# Frequency (times)                             481
# Monetary (c.c. blood)                         481
# Time (months)                                 481
# whether he/she donated blood in March 2007    481
# dtype: int64

# %%
blood_transfusion_data['Time (months)'].describe()
# Out:
# count    748.000000
# mean      34.282086
# std       24.376714
# min        2.000000
# 25%       16.000000
# 50%       28.000000
# 75%       50.000000
# max       98.000000
# Name: Time (months), dtype: float64

# %%
plt.hist(blood_transfusion_data['Time (months)'],bins=5)
plt.xlabel('Time (months)')
plt.ylabel('Count')
plt.title('Figure 7: Histogram Time Distribution')
plt.show()

# %%
blood_transfusion_data.boxplot(column='Time (months)',figsize = (5,5))
plt.title('Figure 8: Boxplot Time Distribution')
plt.show()

# %%
blood_transfusion_data['whether he/she donated blood in March 2007'].describe()
# Out:
# count    748.000000
# mean       0.237968
# std        0.426124
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: whether he/she donated blood in March 2007, dtype: float64

# %%
blood_transfusion_data['whether he/she donated blood in March 2007'].replace(to_replace=0, value='no', inplace=True)
blood_transfusion_data['whether he/she donated blood in March 2007'].replace(to_replace=1, value='yes', inplace=True)
plt.hist(blood_transfusion_data['whether he/she donated blood in March 2007'],bins=5)
labels, counts = np.unique(blood_transfusion_data['whether he/she donated blood in March 2007'], return_counts=True)
plt.bar(labels, counts, align='center')
plt.title('Figure 9: Bar Chart value count of numbers of donor in March 2007')
plt.xlabel('whether he/she donated blood in March 2007')
plt.ylabel('Count')
plt.show()

# %%
blood_transfusion_data['whether he/she donated blood in March 2007'].value_counts().plot(kind='pie',autopct='%2f',figsize = (5,5))
plt.title('Figure 10: Pie Chart of Percentage of numbers of donor in March 2007')
plt.show()

# %% [markdown]
# ## Task 2.2 Relationship Investigation

# %%
blood_transfusion_data.plot(kind='scatter', x='Recency (months)', y='Frequency (times)',figsize=(5,5))
plt.title('Figure 11: Scatter plot showing the relationship between Recency and Frequency')
plt.show()

# %%
blood_transfusion_data.plot(kind='scatter', x='Recency (months)', y='Monetary (c.c. blood)',figsize=(5,5))
plt.title('Figure 12: Scatterplot showing the relationship between Recency and Monetary')
plt.show()

# %%
blood_transfusion_data.plot(kind='scatter', x='Recency (months)', y='Time (months)',figsize=(5,5))
plt.title('Figure 13: Scatterplot showing the relationship between Time (since first donation) and Recency (since last donation)',size =8)
plt.show()

# %%
blood_transfusion_data.plot(kind='scatter', x='Frequency (times)', y='Monetary (c.c. blood)',figsize=(5,5))
plt.title('Figure 14: Scatterplot showing the relationship between Monetary and Frequency',size =8)
plt.show()

# %%
blood_transfusion_data.plot(kind='scatter', x='Frequency (times)', y='Time (months)',figsize=(5,5))
plt.title('Figure 15: Scatterplot showing the relationship between Time (since first donation) and Frequency',size =8)
plt.show()

# %%
blood_transfusion_data.plot(kind='scatter', x='Monetary (c.c. blood)', y='Time (months)',figsize=(5,5))
plt.title('Figure 16: Scatterplot showing the relationship between Time (since first donation) and Monetary',size =8)
plt.show()

# %%
blood_transfusion_data.boxplot(column='Recency (months)',by = 'whether he/she donated blood in March 2007', figsize = (5,5))
plt.title('Figure 17: Boxplot showing the relationship between whether he/she donated blood in March 2007 and Recency',size =12)
plt.show()

# %%
blood_transfusion_data.boxplot(column='Frequency (times)',by = 'whether he/she donated blood in March 2007', figsize = (5,5))
plt.title('Figure 18: Boxplot showing the relationship between whether he/she donated blood in March 2007 and Frequency',size =12)
plt.show()

# %%
blood_transfusion_data.boxplot(column='Monetary (c.c. blood)',by = 'whether he/she donated blood in March 2007', figsize = (5,5))
plt.title('Figure 19: Boxplot showing the relationship between whether he/she donated blood in March 2007 and Monetary',size =12)
plt.show()

# %%
blood_transfusion_data.boxplot(column='Time (months)',by = 'whether he/she donated blood in March 2007', figsize = (5,5))
plt.title('Figure 20: Boxplot showing the relationship between whether he/she donated blood in March 2007 and Time',size =12)
plt.show()

# %% [markdown]
# # Task 3: Data Modelling

# %%
features = blood_transfusion_data[['Recency (months)','Frequency (times)','Monetary (c.c. blood)','Time (months)','whether he/she donated blood in March 2007']]
predict = 'whether he/she donated blood in March 2007'

# %%
X = np.array(features.drop([predict],1))
y = np.array(blood_transfusion_data[predict])

# %% [markdown]
# ## 3.1 Model with train 80% and test 20%

# %% [markdown]
# ## 3.1.1 kNN Classifier

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state = 0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((598, 4), (150, 4), (598,), (150,))

# %%
def first_KNN(n):
    clf = KNeighborsClassifier(n_neighbors=n)
    model = clf.fit(x_train, y_train)
    return model

# %%
acc = 0
for k in range(1,30):
    model = first_KNN(k)
    temp_prediction = model.predict(x_test)
    temp_acc = model.score(x_test,y_test)
    if temp_acc > acc:
        acc = temp_acc
        prediction = temp_prediction
        number_of_neighbor = k
    else:
        acc = acc
print('Our highest accuracy is',acc,'at',number_of_neighbor)
# Out:
# Our highest accuracy is 0.7733333333333333 at 13

# %%
cm = confusion_matrix(y_test,prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix: ')
plt.show()
# Out:
# This is the confusion matrix:

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.77      0.97      0.86       109
#          yes       0.77      0.24      0.37        41
#
#     accuracy                           0.77       150
#    macro avg       0.77      0.61      0.62       150
# weighted avg       0.77      0.77      0.73       150

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.2)
        model = first_KNN(13)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Monetary (c.c. blood)'], dtype='object') 0.76
# Score with Index(['Monetary (c.c. blood)', 'Time (months)'], dtype='object') 0.7733333333333333
# Score with Index(['Frequency (times)'], dtype='object') 0.8266666666666667
# Score with Index(['Frequency (times)'], dtype='object') 0.84

# %% [markdown]
# ## 3.1.2 Decision Tree Classifier

# %%
def DT(criterion_input,max_depth_input,min_sample_leaf_input,X_train,y_train):
    clf = DecisionTreeClassifier(criterion=criterion_input, max_depth=max_depth_input, min_samples_split=2, min_samples_leaf=min_sample_leaf_input, max_features=None)
    model = clf.fit(X_train, y_train)
    return model

# %% [markdown]
# ### 3.1.2.1 Entropy

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state = 0)

# %%
acc = 0
acc_colection = []
for depth in range(1,10):
    for leaf in range(1,10):
        model = DT('entropy',depth,leaf,x_train,y_train)
        temp_prediction = model.predict(x_test)
        temp_acc = model.score(x_test,y_test)
        acc_colection.append(temp_acc)
        if temp_acc > acc:
            acc = temp_acc
            prediction = temp_prediction
            number_max_depth = depth
            min_sample_leaf = leaf
        else:
            acc = acc
print('Our highest accuracy is',acc,'at max depth equal',number_max_depth,'and min sample leaf',min_sample_leaf)
# Out:
# Our highest accuracy is 0.7933333333333333 at max depth equal 5 and min sample leaf 9

# %%
cm = confusion_matrix(y_test, prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix')
plt.show()
# Out:
# This is the confusion matrix

# %%
print (classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.82      0.91      0.86       109
#          yes       0.67      0.49      0.56        41
#
#     accuracy                           0.79       150
#    macro avg       0.75      0.70      0.71       150
# weighted avg       0.78      0.79      0.78       150

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.2)
        model = DT('entropy',5,9,x_train,y_train)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Recency (months)'], dtype='object') 0.78
# Score with Index(['Recency (months)', 'Frequency (times)'], dtype='object') 0.7866666666666666
# Score with Index(['Frequency (times)'], dtype='object') 0.7933333333333333
# Score with Index(['Frequency (times)'], dtype='object') 0.8133333333333334
# Score with Index(['Monetary (c.c. blood)'], dtype='object') 0.8466666666666667

# %% [markdown]
# ### 3.1.2.2 Gini

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state = 0)

# %%
acc = 0
for k in range(1,10):
    for i in range(1,10):
        model = DT('gini',k,i,x_train,y_train)
        temp_prediction = model.predict(x_test)
        temp_acc = model.score(x_test,y_test)
        if temp_acc > acc:
            acc = temp_acc
            prediction = temp_prediction
            number_max_depth = k
            min_sample_leaf = i
        else:
            acc = acc
print('Our highest accuracy is',acc,'at max depth equal',number_max_depth,'and min sample leaf',min_sample_leaf)
# Out:
# Our highest accuracy is 0.8 at max depth equal 9 and min sample leaf 4

# %%
cm = confusion_matrix(y_test, prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix')
plt.show()
# Out:
# This is the confusion matrix

# %%
print (classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.81      0.95      0.87       109
#          yes       0.76      0.39      0.52        41
#
#     accuracy                           0.80       150
#    macro avg       0.78      0.67      0.70       150
# weighted avg       0.79      0.80      0.78       150

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.2)
        model = DT('gini',6,5,x_train,y_train)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Time (months)'], dtype='object') 0.7533333333333333
# Score with Index(['Time (months)', 'Recency (months)'], dtype='object') 0.7666666666666667
# Score with Index(['Time (months)', 'Recency (months)', 'Monetary (c.c. blood)'], dtype='object') 0.8133333333333334
# Score with Index(['Monetary (c.c. blood)'], dtype='object') 0.84

# %% [markdown]
# ## 3.2 Model with train 60% and test 40%

# %% [markdown]
# ## 3.2.1 kNN Classifier

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4,random_state = 0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((448, 4), (300, 4), (448,), (300,))

# %%
def second_KNN(n):
    clf = KNeighborsClassifier(n_neighbors=n)
    model = clf.fit(x_train, y_train)
    return model

# %%
acc = 0
for k in range(1,30):
    model = second_KNN(k)
    temp_prediction = model.predict(x_test)
    temp_acc = model.score(x_test,y_test)
    if temp_acc > acc:
        acc = temp_acc
        prediction = temp_prediction
        number_of_neighbor = k
    else:
        acc = acc
print('Our highest accuracy is',acc,'at',number_of_neighbor)
# Out:
# Our highest accuracy is 0.7933333333333333 at 10

# %%
cm = confusion_matrix(y_test,prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix')
plt.show()
# Out:
# This is the confusion matrix

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.79      1.00      0.88       226
#          yes       0.93      0.18      0.30        74
#
#     accuracy                           0.79       300
#    macro avg       0.86      0.59      0.59       300
# weighted avg       0.82      0.79      0.73       300

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.4)
        model = second_KNN(10)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Frequency (times)'], dtype='object') 0.7233333333333334
# Score with Index(['Frequency (times)', 'Recency (months)'], dtype='object') 0.7433333333333333
# Score with Index(['Frequency (times)', 'Recency (months)', 'Monetary (c.c. blood)'], dtype='object') 0.7633333333333333
# Score with Index(['Monetary (c.c. blood)'], dtype='object') 0.7666666666666667
# Score with Index(['Monetary (c.c. blood)', 'Time (months)'], dtype='object') 0.7766666666666666
# Score with Index(['Time (months)'], dtype='object') 0.8
# Score with Index(['Recency (months)'], dtype='object') 0.8066666666666666

# %% [markdown]
# ## 3.2.2 Decision Tree Classifier

# %% [markdown]
# ### 3.2.2.1 Entropy

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4,random_state = 0)

# %%
acc = 0
for k in range(1,10):
    for i in range(1,10):
        model = DT('entropy',k,i,x_train,y_train)
        temp_prediction = model.predict(x_test)
        temp_acc = model.score(x_test,y_test)
        if temp_acc > acc:
            acc = temp_acc
            prediction = temp_prediction
            number_max_depth = k
            min_sample_leaf = i
        else:
            acc = acc
print('Our highest accuracy is',acc,'at max depth equal',number_max_depth,'and min sample leaf',min_sample_leaf)
# Out:
# Our highest accuracy is 0.81 at max depth equal 5 and min sample leaf 8

# %%
cm = confusion_matrix(y_test, prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix')
plt.show()
# Out:
# This is the confusion matrix

# %%
print (classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.84      0.92      0.88       226
#          yes       0.67      0.46      0.54        74
#
#     accuracy                           0.81       300
#    macro avg       0.75      0.69      0.71       300
# weighted avg       0.80      0.81      0.80       300

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.4)
        model = DT('entropy',4,2,x_train,y_train)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Time (months)'], dtype='object') 0.7566666666666667
# Score with Index(['Time (months)', 'Frequency (times)'], dtype='object') 0.7733333333333333
# Score with Index(['Time (months)', 'Frequency (times)', 'Recency (months)'], dtype='object') 0.79
# Score with Index(['Frequency (times)'], dtype='object') 0.7966666666666666
# Score with Index(['Recency (months)'], dtype='object') 0.8
# Score with Index(['Time (months)'], dtype='object') 0.8033333333333333

# %% [markdown]
# ### 3.2.2.1 Gini

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4,random_state = 0)

# %%
acc = 0
for k in range(1,10):
    for i in range(1,10):
        model = DT('gini',k,i,x_train,y_train)
        temp_prediction = model.predict(x_test)
        temp_acc = model.score(x_test,y_test)
        if temp_acc > acc:
            acc = temp_acc
            prediction = temp_prediction
            number_max_depth = k
            min_sample_leaf = i
        else:
            acc = acc
print('Our highest accuracy is',acc,'at max depth equal',number_max_depth,'and min sample leaf',min_sample_leaf)
# Out:
# Our highest accuracy is 0.8033333333333333 at max depth equal 4 and min sample leaf 2

# %%
cm = confusion_matrix(y_test, prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix')
plt.show()
# Out:
# This is the confusion matrix

# %%
print (classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.85      0.90      0.87       226
#          yes       0.62      0.51      0.56        74
#
#     accuracy                           0.80       300
#    macro avg       0.74      0.71      0.72       300
# weighted avg       0.79      0.80      0.80       300

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.4)
        model = DT('gini',4,2,x_train,y_train)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Monetary (c.c. blood)'], dtype='object') 0.7366666666666667
# Score with Index(['Monetary (c.c. blood)', 'Recency (months)'], dtype='object') 0.7466666666666667
# Score with Index(['Monetary (c.c. blood)', 'Recency (months)', 'Frequency (times)'], dtype='object') 0.75
# Score with Index(['Monetary (c.c. blood)', 'Recency (months)', 'Frequency (times)',
#        'Time (months)'],
#       dtype='object') 0.7633333333333333
# Score with Index(['Frequency (times)'], dtype='object') 0.77
# Score with Index(['Recency (months)'], dtype='object') 0.78
# Score with Index(['Monetary (c.c. blood)'], dtype='object') 0.7933333333333333
# Score with Index(['Recency (months)'], dtype='object') 0.8066666666666666
# Score with Index(['Time (months)'], dtype='object') 0.8133333333333334

# %% [markdown]
# ## 3.3 Model with train 40% and test 60%

# %% [markdown]
# ## 3.3.1 kNN Classifier

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.6,random_state = 0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((299, 4), (449, 4), (299,), (449,))

# %%
def third_KNN(n):
    clf = KNeighborsClassifier(n_neighbors=n)
    model = clf.fit(x_train, y_train)
    return model

# %%
acc = 0
for k in range(1,30):
    model = third_KNN(k)
    temp_prediction = model.predict(x_test)
    temp_acc = model.score(x_test,y_test)
    if temp_acc > acc:
        acc = temp_acc
        prediction = temp_prediction
        number_of_neighbor = k
    else:
        acc = acc
print('Our highest accuracy is',acc,'at',number_of_neighbor)
# Out:
# Our highest accuracy is 0.7661469933184856 at 26

# %%
cm = confusion_matrix(y_test,prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix')
plt.show()
# Out:
# This is the confusion matrix

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.77      1.00      0.87       344
#          yes       0.00      0.00      0.00       105
#
#     accuracy                           0.77       449
#    macro avg       0.38      0.50      0.43       449
# weighted avg       0.59      0.77      0.66       449
# D:\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.6)
        model = third_KNN(26)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Frequency (times)'], dtype='object') 0.7505567928730512
# Score with Index(['Frequency (times)', 'Monetary (c.c. blood)'], dtype='object') 0.755011135857461
# Score with Index(['Frequency (times)', 'Monetary (c.c. blood)', 'Time (months)'], dtype='object') 0.77728285077951
# Score with Index(['Time (months)'], dtype='object') 0.7817371937639198
# Score with Index(['Recency (months)'], dtype='object') 0.7928730512249443

# %% [markdown]
# ## 3.2.3 Decision Tree Classifier

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.6,random_state = 0)

# %% [markdown]
# ### 3.2.3.1 Entropy

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.6,random_state = 0)

# %%
acc = 0
for k in range(1,10):
    for i in range(1,10):
        model = DT('entropy',k,i,x_train,y_train)
        temp_prediction = model.predict(x_test)
        temp_acc = model.score(x_test,y_test)
        if temp_acc > acc:
            acc = temp_acc
            prediction = temp_prediction
            number_max_depth = k
            min_sample_leaf = i
        else:
            acc = acc
print('Our highest accuracy is',acc,'at max depth equal',number_max_depth,'and min sample leaf',min_sample_leaf)
# Out:
# Our highest accuracy is 0.7928730512249443 at max depth equal 4 and min sample leaf 6

# %%
cm = confusion_matrix(y_test, prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix')
plt.show()
# Out:
# This is the confusion matrix

# %%
print (classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.83      0.92      0.87       344
#          yes       0.59      0.39      0.47       105
#
#     accuracy                           0.79       449
#    macro avg       0.71      0.65      0.67       449
# weighted avg       0.77      0.79      0.78       449

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.6)
        model = DT('entropy',4,6,x_train,y_train)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Recency (months)'], dtype='object') 0.7305122494432071
# Score with Index(['Recency (months)', 'Monetary (c.c. blood)'], dtype='object') 0.77728285077951
# Score with Index(['Recency (months)', 'Monetary (c.c. blood)', 'Frequency (times)'], dtype='object') 0.799554565701559

# %% [markdown]
# ### 3.2.3.2 Gini

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.6,random_state = 0)

# %%
acc = 0
for k in range(1,10):
    for i in range(1,10):
        model = DT('entropy',k,i,x_train,y_train)
        temp_prediction = model.predict(x_test)
        temp_acc = model.score(x_test,y_test)
        if temp_acc > acc:
            acc = temp_acc
            prediction = temp_prediction
            number_max_depth = k
            min_sample_leaf = i
        else:
            acc = acc
print('Our highest accuracy is',acc,'at max depth equal',number_max_depth,'and min sample leaf',min_sample_leaf)
# Out:
# Our highest accuracy is 0.7928730512249443 at max depth equal 4 and min sample leaf 6

# %%
cm = confusion_matrix(y_test, prediction)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {:.3f}'.format(acc)
plt.title(all_sample_title, size = 15);
print('This is the confusion matrix')
plt.show()
# Out:
# This is the confusion matrix

# %%
print (classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.83      0.92      0.87       344
#          yes       0.59      0.39      0.47       105
#
#     accuracy                           0.79       449
#    macro avg       0.71      0.65      0.67       449
# weighted avg       0.77      0.79      0.78       449

# %%
col_num = X.shape[1]
cur_Max_accuracy = 0
for i in range(0,50):
    new_ind = []
    col_Ind_Random = shuffle(range(0,col_num))
    for cur_features in range(0,col_num):
        new_ind.append(col_Ind_Random[cur_features])
        newData = X[:,new_ind].copy()
        x_train, x_test, y_train, y_test = train_test_split(newData, y, test_size=0.6)
        model = DT('gini',4,6,x_train,y_train)
        cur_score = model.score(x_test,y_test)
        if cur_score <= cur_Max_accuracy:
            new_ind.remove(col_Ind_Random[cur_features])
        else:
            cur_Max_accuracy = cur_score
            print("Score with",features.columns[new_ind],cur_score)
# Out:
# Score with Index(['Monetary (c.c. blood)'], dtype='object') 0.7661469933184856
# Score with Index(['Monetary (c.c. blood)', 'Frequency (times)'], dtype='object') 0.7728285077951003
# Score with Index(['Recency (months)'], dtype='object') 0.7750556792873051
# Score with Index(['Recency (months)'], dtype='object') 0.7928730512249443
# Score with Index(['Frequency (times)'], dtype='object') 0.799554565701559
